# %% [markdown]
# <h1 align="center" style="color:green">Matplotlib Tutorial: pyplot.plot format strings and other options</h1>

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=[1,2,3,4,5,6,7]
y=[50,51,52,48,47,49,46]

# %%
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather')

plt.plot(x,y,'g*--')
plt.show()

# %%
# Same effect as 'b+' format string
plt.plot(x,y,color='blue',marker='<',linestyle='--')

# %% [markdown]
# <h3 style="color:purple">markersize</h3>

# %%
plt.plot(x,y,color='blue',marker='<',linewidth=4,linestyle='--',markersize=10)
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather')
plt.show()

# %% [markdown]
# <h3 style="color:purple">alpha property to control transparency of line chart</h3>

# %%
plt.plot(x,y,'r<',alpha=0.9,markersize=40) # alpha can be specified on a scale 0 to 1
